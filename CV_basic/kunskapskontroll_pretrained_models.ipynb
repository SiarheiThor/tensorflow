# %% [markdown]
# # Pretrained Models - Kunskapskontroll

# %% [markdown]
# **Obligatoriskt att fylla i uppgifterna nedan.**
#
# Namn: Siarhei Thor
#
# Vem du har presenterat för: -
#
# Datum då du presenterade: -
#
# **Kunskapskontrollen lämnas in på Omniway.**

# %% [markdown]
# **It is possible to load pretrained models which is a powerful concept.**

# %% [markdown]
# Model implementation:
# https://keras.io/api/applications/#usage-examples-for-image-classification-models
#
# Class list for ResNet50, for example tennis ball is 852:
# https://deeplearning.cms.waikato.ac.nz/user-guide/class-maps/IMAGENET/

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
model = ResNet50(weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 [==============================] - 3s 0us/step

# %%
# img_path = 'zebra.jpg'
# img_path = 'linjal.jpg'
img_path = 'data/Screenshot 2024-05-18 at 10.27.14.png'
img = image.load_img(img_path, target_size=(224, 224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(img)
x.shape
# Out:
# (224, 224, 3)

# %%
x = np.expand_dims(x, axis=0)
x.shape
# Out:
# (1, 224, 224, 3)

# %%
# https://www.tensorflow.org/api_docs/python/tf/keras/applications/resnet50/preprocess_input
x = preprocess_input(x)

# %%
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# 1/1 [==============================] - 0s 73ms/step
# Predicted: [('n02099601', 'golden_retriever', 0.9694762), ('n02102318', 'cocker_spaniel', 0.008944214), ('n02099712', 'Labrador_retriever', 0.004365477)]

# %% [markdown]
# # 1. Take some pictures yourself and predict their class.

# %%
import matplotlib.pyplot as plt
def inference(image_path):
    img = image.load_img(image_path, target_size=(224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    preds = model.predict(x)
    #print('Predicted:', decode_predictions(preds, top=3)[0])
    plt.imshow(img)
    plt.axis('off')  # Turn off axis numbers and ticks
    plt.show()
    
    return decode_predictions(preds, top=3)[0]

# %%
inference(img_path)
# Out:
# 1/1 [==============================] - 0s 62ms/step
# [('n02099601', 'golden_retriever', 0.9694762),
#  ('n02102318', 'cocker_spaniel', 0.008944214),
#  ('n02099712', 'Labrador_retriever', 0.004365477)]

# %%
inference('data/IMG_1104.jpg')
# Out:
# 1/1 [==============================] - 0s 63ms/step
# [('n02980441', 'castle', 0.6114898),
#  ('n09332890', 'lakeside', 0.24120866),
#  ('n03028079', 'church', 0.046632312)]

# %%
inference('data/Screenshot 2024-05-18 at 11.00.14.png')
# Out:
# 1/1 [==============================] - 0s 65ms/step
# [('n03393912', 'freight_car', 0.28794947),
#  ('n03776460', 'mobile_home', 0.21422763),
#  ('n03384352', 'forklift', 0.15219682)]

# %% [markdown]
# # 2. Answer the question: Why is "Pretrained models" a very powerful concept?

# %% [markdown]
# Because it is wise to buiuld upon somebodies elses great work to drive innovation.
